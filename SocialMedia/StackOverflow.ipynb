# %%
import requests

# %%
response = requests.get('http://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'items': [{'tags': ['java', 'android'],
#    'owner': {'account_id': 23025741,
#     'reputation': 1,
#     'user_id': 17146022,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJzmQ9ZHIVljA3543p5TPr_SCajotZwZ_H4ArLg=k-s256',
#     'display_name': 'D Com',
#     'link': 'https://stackoverflow.com/users/17146022/d-com'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482041,
#    'creation_date': 1634481696,
#    'last_edit_date': 1634482041,
#    'question_id': 69605424,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605424/identifying-a-number-that-is-not-stored-in-the-contacts-during-an-incoming-or-ou',
#    'title': 'identifying a number that is not stored in the contacts during an incoming or outgoing call'},
#   {'tags': ['visual-studio-code', 'vscode-settings'],
#    'owner': {'account_id': 23058719,
#     'reputation': 1,
#     'user_id': 17174393,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7daa0d95dbf4a9bee2ac3c75d469b999?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'poohe',
#     'link': 'https://stackoverflow.com/users/17174393/poohe'},
#    'is_answered': False,
#    'view_count': 16,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482040,
#    'creation_date': 1634474263,
#    'last_edit_date': 1634482040,
#    'question_id': 69604408,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69604408/vs-code-hide-underline-how-can-i-hide-there-underlines',
#    'title': 'VS Code hide underline__ How can I hide there underlines?'},
#   {'tags': ['r', 'data-science'],
#    'owner': {'account_id': 21254785,
#     'reputation': 1,
#     'user_id': 15636481,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/0d5a28e574a2148bbe619048131fdd97?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'metanoia',
#     'link': 'https://stackoverflow.com/users/15636481/metanoia'},
#    'is_answered': False,
#    'view_count': 26,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1634482039,
#    'creation_date': 1634471481,
#    'last_edit_date': 1634482039,
#    'question_id': 69604059,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69604059/error-reading-manipulating-and-saving-large-dataframes-using-for-loop-in-r',
#    'title': 'Error: reading, manipulating and saving large dataframes using for loop in R'},
#   {'tags': ['c#',
#     'asp.net-core',
#     'visual-studio-2019',
#     'generic-list',
#     'connected-services'],
#    'owner': {'account_id': 10143815,
#     'reputation': 455,
#     'user_id': 7492645,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/4R1JF.jpg?s=256&g=1',
#     'display_name': 'Ross Kelly',
#     'link': 'https://stackoverflow.com/users/7492645/ross-kelly'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482036,
#    'creation_date': 1634481393,
#    'last_edit_date': 1634482036,
#    'question_id': 69605385,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605385/visual-studio-project-adding-connected-services-using-generic-list-fails',
#    'title': 'Visual Studio Project Adding Connected Services using Generic List Fails'},
#   {'tags': ['python'],
#    'owner': {'account_id': 23058503,
#     'reputation': 1,
#     'user_id': 17174210,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e1a8997368d71a4883ff7b685db02efd?s=256&d=identicon&r=PG',
#     'display_name': 'menaka',
#     'link': 'https://stackoverflow.com/users/17174210/menaka'},
#    'is_answered': False,
#    'view_count': 36,
#    'answer_count': 3,
#    'score': -6,
#    'last_activity_date': 1634482034,
#    'creation_date': 1634472537,
#    'question_id': 69604197,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69604197/how-to-install-numpy-and-pandas-in-python',
#    'title': 'How to install numpy and pandas in python'},
#   {'tags': ['android', 'firebase', 'kotlin', 'google-cloud-firestore'],
#    'owner': {'account_id': 22929915,
#     'reputation': 1,
#     'user_id': 17064403,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJyusPzzgFTrI0da5g1mmUCJJigRYSvI2YRkwfpg=k-s256',
#     'display_name': 'batuhan diler',
#     'link': 'https://stackoverflow.com/users/17064403/batuhan-diler'},
#    'is_answered': False,
#    'view_count': 10,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482030,
#    'creation_date': 1634479825,
#    'last_edit_date': 1634482030,
#    'question_id': 69605150,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605150/how-can-i-finish-my-function-in-firestore-listener',
#    'title': 'How can i finish my function in Firestore listener?'},
#   {'tags': ['firebase', 'unity3d', 'google-cloud-functions'],
#    'owner': {'account_id': 11891674,
#     'reputation': 3,
#     'user_id': 8702313,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7207447f2da589f89df81343d53ab680?s=256&d=identicon&r=PG',
#     'display_name': 'Sevdanski',
#     'link': 'https://stackoverflow.com/users/8702313/sevdanski'},
#    'is_answered': True,
#    'view_count': 16,
#    'accepted_answer_id': 69592628,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1634482027,
#    'creation_date': 1634356218,
#    'last_edit_date': 1634482027,
#    'question_id': 69592503,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69592503/can-you-use-unity-firebase-auth-with-c-google-cloud-functions',
#    'title': 'Can you use Unity / Firebase Auth with C# google cloud functions?'},
#   {'tags': ['tcl'],
#    'owner': {'account_id': 23059627,
#     'reputation': 1,
#     'user_id': 17175169,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjVE-LmBcSAZ0ILu7EHJprl1Foba799696RMb2b=k-s256',
#     'display_name': 'Prince Kumar',
#     'link': 'https://stackoverflow.com/users/17175169/prince-kumar'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482017,
#    'creation_date': 1634482017,
#    'question_id': 69605462,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605462/write-a-procedure-to-generate-a-single-list-by-reading-the-user-input-from-comm',
#    'title': 'Write a procedure to generate a single list, by reading the user input from command line in TCL'},
#   {'tags': ['reactjs', 'firebase', 'react-native', 'expo', 'react-navigation'],
#    'owner': {'account_id': 10442364,
#     'reputation': 105,
#     'user_id': 13355002,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Sp5MB.jpg?s=256&g=1',
#     'display_name': 'BISHAL SAHA',
#     'link': 'https://stackoverflow.com/users/13355002/bishal-saha'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1634482014,
#    'creation_date': 1634479545,
#    'question_id': 69605104,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605104/cant-find-variable-user-i-am-using-firebase-auth-and-the-latest-sdk-expo-sdk',
#    'title': 'can&#39;t find variable: user. I am using firebase auth and the latest SDK, expo SDK 42, react navigation 6.x.x'},
#   {'tags': ['python', 'pandas', 'dataframe'],
#    'owner': {'account_id': 20281579,
#     'reputation': 83,
#     'user_id': 14875201,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5d78ac92b5d729e2bbddb04bb186dd86?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'mike',
#     'link': 'https://stackoverflow.com/users/14875201/mike'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482012,
#    'creation_date': 1634482012,
#    'question_id': 69605460,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605460/group-values-in-pandas-dataframe-by-min',
#    'title': 'Group values in pandas dataframe by min'},
#   {'tags': ['html', 'typescript', 'window.open'],
#    'owner': {'account_id': 5278912,
#     'reputation': 1566,
#     'user_id': 4214922,
#     'user_type': 'registered',
#     'accept_rate': 57,
#     'profile_image': 'https://graph.facebook.com/100003077452923/picture?type=large',
#     'display_name': 'Mike Ottink',
#     'link': 'https://stackoverflow.com/users/4214922/mike-ottink'},
#    'is_answered': False,
#    'view_count': 44,
#    'bounty_amount': 50,
#    'bounty_closes_date': 1635046047,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1634482012,
#    'creation_date': 1633994669,
#    'last_edit_date': 1634037805,
#    'question_id': 69533474,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69533474/how-can-i-open-a-url-in-a-new-window-on-safari-iphone',
#    'title': 'How can I open a url in a new window on safari iphone'},
#   {'tags': ['json', 'azure', 'azure-powershell', 'azure-management-groups'],
#    'owner': {'account_id': 16832554,
#     'reputation': 5,
#     'user_id': 12170152,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-VgmxbKSj7Is/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rdM7Pwg-shES1oN2LlC4Fj568wR9Q/photo.jpg?sz=256',
#     'display_name': 'Divyansh Saxena',
#     'link': 'https://stackoverflow.com/users/12170152/divyansh-saxena'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482011,
#    'creation_date': 1634482011,
#    'question_id': 69605458,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605458/not-able-to-create-new-management-group-in-azure-new-azmanagementgroup',
#    'title': 'Not able to create new Management Group in Azure - New-AzManagementGroup'},
#   {'tags': ['java', 'android', 'image', 'capture'],
#    'owner': {'account_id': 22589321,
#     'reputation': 9,
#     'user_id': 16772693,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a69a8c86293ae9caa63b9e2ce3ae220b?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'ninh312',
#     'link': 'https://stackoverflow.com/users/16772693/ninh312'},
#    'is_answered': False,
#    'view_count': 21,
#    'closed_date': 1634458591,
#    'answer_count': 0,
#    'score': -2,
#    'last_activity_date': 1634482010,
#    'creation_date': 1634401233,
#    'last_edit_date': 1634482010,
#    'question_id': 69597433,
#    'link': 'https://stackoverflow.com/questions/69597433/how-can-i-capture-part-of-the-screen',
#    'closed_reason': 'Duplicate',
#    'title': 'How can I capture part of the screen?'},
#   {'tags': ['java', 'android', 'singleton'],
#    'owner': {'account_id': 23038623,
#     'reputation': 3,
#     'user_id': 17157049,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c137ecd9000f09db78d48d620d9006cf?s=256&d=identicon&r=PG',
#     'display_name': 'CanonSAS',
#     'link': 'https://stackoverflow.com/users/17157049/canonsas'},
#    'is_answered': True,
#    'view_count': 65,
#    'closed_date': 1634338404,
#    'accepted_answer_id': 69581380,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1634482004,
#    'creation_date': 1634282997,
#    'last_edit_date': 1634288843,
#    'question_id': 69581286,
#    'link': 'https://stackoverflow.com/questions/69581286/android-singleton',
#    'closed_reason': 'Needs details or clarity',
#    'title': 'Android Singleton'},
#   {'tags': ['google-cloud-platform', 'google-cloud-shell'],
#    'owner': {'account_id': 8552378,
#     'reputation': 1445,
#     'user_id': 6408940,
#     'user_type': 'registered',
#     'accept_rate': 37,
#     'profile_image': 'https://lh6.googleusercontent.com/-vbyGrdWnlGo/AAAAAAAAAAI/AAAAAAAAAA8/9vzdkPT4fk4/photo.jpg?sz=256',
#     'display_name': 'Valentin Coudert',
#     'link': 'https://stackoverflow.com/users/6408940/valentin-coudert'},
#    'is_answered': True,
#    'view_count': 30,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1634482004,
#    'creation_date': 1634140943,
#    'last_edit_date': 1634482004,
#    'question_id': 69558710,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69558710/wrong-keyboard-on-google-cloud-shell',
#    'title': 'Wrong keyboard on Google Cloud Shell'},
#   {'tags': ['com', 'vb6', 'exe', 'permission-denied', 'dcom'],
#    'owner': {'account_id': 22985207,
#     'reputation': 11,
#     'user_id': 17111517,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6b7ef51cd6eaee712d1638b7bdd5e02f?s=256&d=identicon&r=PG',
#     'display_name': 'Donax',
#     'link': 'https://stackoverflow.com/users/17111517/donax'},
#    'is_answered': False,
#    'view_count': 40,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482003,
#    'creation_date': 1634316014,
#    'last_edit_date': 1634482003,
#    'question_id': 69588006,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69588006/why-i-got-error-70-permission-denied-when-write-data-to-a-variable',
#    'title': 'Why I got error 70: Permission denied when write data to a variable'},
#   {'tags': ['python', 'pandas'],
#    'owner': {'account_id': 8491955,
#     'reputation': 690,
#     'user_id': 6367971,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a657e3d2d653a9fd7743a9ba5f34e692?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'MSD',
#     'link': 'https://stackoverflow.com/users/6367971/msd'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634482002,
#    'creation_date': 1634482002,
#    'question_id': 69605457,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605457/pandas-drop-rows-appearing-above-below-string-match',
#    'title': 'Pandas drop rows appearing above/below string match'},
#   {'tags': ['go', 'gorilla'],
#    'owner': {'account_id': 255381,
#     'reputation': 1408,
#     'user_id': 535401,
#     'user_type': 'registered',
#     'accept_rate': 40,
#     'profile_image': 'https://i.stack.imgur.com/ltK0q.jpg?s=256&g=1',
#     'display_name': 'JakeRobb',
#     'link': 'https://stackoverflow.com/users/535401/jakerobb'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634481996,
#    'creation_date': 1634481912,
#    'last_edit_date': 1634481996,
#    'question_id': 69605448,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605448/how-can-i-make-type-assertions-against-an-anonymous-function',
#    'title': 'How can I make type assertions against an anonymous function?'},
#   {'tags': ['python', 'twitter', 'error-handling', 'bz2', 'ijson'],
#    'owner': {'account_id': 20633504,
#     'reputation': 3,
#     'user_id': 15147795,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/319f5c17f606ca1299f5eb7e3e87a086?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'James',
#     'link': 'https://stackoverflow.com/users/15147795/james'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1634481990,
#    'creation_date': 1634463418,
#    'last_edit_date': 1634465408,
#    'question_id': 69603013,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69603013/python-ijson-parse-error-trailing-garbage-bz2-decompress',
#    'title': 'Python ijson - parse error: trailing garbage // bz2.decompress()'},
#   {'tags': ['go', 'polymorphism'],
#    'owner': {'account_id': 23058510,
#     'reputation': 1,
#     'user_id': 17174217,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5e942f0af0e25597fc81ada8df81da7c?s=256&d=identicon&r=PG',
#     'display_name': 'Balancing Ray',
#     'link': 'https://stackoverflow.com/users/17174217/balancing-ray'},
#    'is_answered': False,
#    'view_count': 16,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634481989,
#    'creation_date': 1634478786,
#    'last_edit_date': 1634481989,
#    'question_id': 69604990,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69604990/polymorphism-in-go-how-to-create-common-imodel-interface-with-merge-compare-me',
#    'title': 'Polymorphism in Go. How to create common IModel interface with Merge, Compare methods, that need to work with another IModel argument?'},
#   {'tags': ['octave'],
#    'owner': {'account_id': 18337451,
#     'reputation': 1,
#     'user_id': 13354538,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/25afdade6867084777fafad4af1bca28?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'amberlacsina',
#     'link': 'https://stackoverflow.com/users/13354538/amberlacsina'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634481979,
#    'creation_date': 1634481979,
#    'question_id': 69605455,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605455/how-do-you-make-an-if-statement-in-octave-that-would-switch-the-row-that-has-a-z',
#    'title': 'How do you make an if-statement in Octave that would switch the row that has a zero pivot element with the row that has a nonzero pivot element?'},
#   {'tags': ['django', 'django-rest-framework'],
#    'owner': {'account_id': 14672026,
#     'reputation': 596,
#     'user_id': 10596249,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bac3d74051475e161c49399d542aa543?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'soubhagya',
#     'link': 'https://stackoverflow.com/users/10596249/soubhagya'},
#    'is_answered': False,
#    'view_count': 34,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1634481965,
#    'creation_date': 1634359354,
#    'last_edit_date': 1634481965,
#    'question_id': 69592725,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69592725/drf-create-manytomany-fields',
#    'title': 'drf create manytomany fields'},
#   {'tags': ['django'],
#    'owner': {'account_id': 6141243,
#     'reputation': 11,
#     'user_id': 4788604,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-w48CQWOIayk/AAAAAAAAAAI/AAAAAAAAAiY/3Q38FjZq3m8/photo.jpg?sz=256',
#     'display_name': 'infected skittle',
#     'link': 'https://stackoverflow.com/users/4788604/infected-skittle'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634481962,
#    'creation_date': 1634481962,
#    'question_id': 69605454,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605454/django-admin-account-page-group-display',
#    'title': 'Django | admin account page group display'},
#   {'tags': ['typescript', 'constructor', 'overloading'],
#    'owner': {'account_id': 1900094,
#     'reputation': 5051,
#     'user_id': 1716118,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/9f07697833f838995450b9fea7504cd9?s=256&d=identicon&r=PG',
#     'display_name': 'Ted',
#     'link': 'https://stackoverflow.com/users/1716118/ted'},
#    'is_answered': True,
#    'view_count': 319185,
#    'answer_count': 18,
#    'score': 495,
#    'last_activity_date': 1634481954,
#    'creation_date': 1349243288,
#    'last_edit_date': 1549235902,
#    'question_id': 12702548,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/12702548/constructor-overload-in-typescript',
#    'title': 'Constructor overload in TypeScript'},
#   {'tags': ['python', 'pygame'],
#    'owner': {'account_id': 22893641,
#     'reputation': 3,
#     'user_id': 17033444,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c4928f8b06857f08cdf26c3072314e28?s=256&d=identicon&r=PG',
#     'display_name': 'kaneaston',
#     'link': 'https://stackoverflow.com/users/17033444/kaneaston'},
#    'is_answered': False,
#    'view_count': 7,
#    'closed_date': 1634482025,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634481940,
#    'creation_date': 1634481940,
#    'question_id': 69605452,
#    'link': 'https://stackoverflow.com/questions/69605452/why-wont-my-button-work-while-program-runs',
#    'closed_reason': 'Duplicate',
#    'title': 'Why wont my button work while program runs?'},
#   {'tags': ['c++', 'c++17', 'implicit-conversion'],
#    'owner': {'account_id': 903892,
#     'reputation': 8860,
#     'user_id': 939259,
#     'user_type': 'registered',
#     'accept_rate': 64,
#     'profile_image': 'https://www.gravatar.com/avatar/4ee12a004bdd48dab9a040fae4aa51f6?s=256&d=identicon&r=PG',
#     'display_name': 'Thomas Johnson',
#     'link': 'https://stackoverflow.com/users/939259/thomas-johnson'},
#    'is_answered': True,
#    'view_count': 58,
#    'accepted_answer_id': 69601732,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1634481936,
#    'creation_date': 1634449554,
#    'last_edit_date': 1634481936,
#    'question_id': 69601640,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69601640/how-can-i-get-c-to-prefer-converting-char-to-string-view-instead-of-bool',
#    'title': 'How can I get C++ to prefer converting char* to string_view instead of bool?'},
#   {'tags': ['r', 'performance', 'shiny', 'profiling', 'profvis'],
#    'owner': {'account_id': 15836004,
#     'reputation': 11,
#     'user_id': 11425835,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f9c8b49c16bb5bfb820225f9cdc388a6?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'chrisgeo',
#     'link': 'https://stackoverflow.com/users/11425835/chrisgeo'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1634481934,
#    'creation_date': 1634307008,
#    'last_edit_date': 1634481934,
#    'question_id': 69586077,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69586077/improve-profvis-performance-for-profiling-shiny-app',
#    'title': 'Improve profvis performance for profiling shiny app'},
#   {'tags': ['google-app-engine',
#     'google-cloud-platform',
#     'google-cloud-load-balancer'],
#    'owner': {'account_id': 3563801,
#     'reputation': 1,
#     'user_id': 7591597,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-Hgx4E6O00BQ/AAAAAAAAAAI/AAAAAAAADRM/6HydCqcc24w/photo.jpg?sz=256',
#     'display_name': 'Danushka Stanley',
#     'link': 'https://stackoverflow.com/users/7591597/danushka-stanley'},
#    'is_answered': True,
#    'view_count': 24,
#    'accepted_answer_id': 69605451,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1634481932,
#    'creation_date': 1634132589,
#    'last_edit_date': 1634364882,
#    'question_id': 69556686,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69556686/https-regional-traffic-route-to-specific-resource-google-cloud',
#    'title': 'HTTP(S) Regional traffic route to specific resource - Google Cloud'},
#   {'tags': ['pandas', 'dataframe', 'group-by', 'apply'],
#    'owner': {'account_id': 1224386,
#     'reputation': 569,
#     'user_id': 3521099,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://www.gravatar.com/avatar/a93fc9fa5ee3a137cb47293b9a277eb9?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Ramirez',
#     'link': 'https://stackoverflow.com/users/3521099/ramirez'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1634481919,
#    'creation_date': 1634477519,
#    'question_id': 69604817,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69604817/when-using-df-groupbycolumn-apply-get-the-groupby-column-within-the-apply',
#    'title': 'When using &#39;df.groupby(column).apply()&#39; get the groupby column within the &#39;apply&#39; context?'},
#   {'tags': ['python', 'csv'],
#    'owner': {'account_id': 23059450,
#     'reputation': 1,
#     'user_id': 17175024,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/eaba069e96d961a01ac4b5a0783f11b3?s=256&d=identicon&r=PG',
#     'display_name': 'CodingPenguin',
#     'link': 'https://stackoverflow.com/users/17175024/codingpenguin'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1634481913,
#    'creation_date': 1634481913,
#    'question_id': 69605449,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69605449/csv-error-line-contains-nul-for-a-new-csv-file',
#    'title': '_csv.Error: line contains NUL for a new CSV file'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 280}

# %%
for i in response.json()['items']:
    print('Tags: ' + str(i['tags']))
    print('Title: ' + i['title'])
    print()
# Out:
# Tags: ['java', 'android']
# Title: identifying a number that is not stored in the contacts during an incoming or outgoing call
#
# Tags: ['visual-studio-code', 'vscode-settings']
# Title: VS Code hide underline__ How can I hide there underlines?
#
# Tags: ['r', 'data-science']
# Title: Error: reading, manipulating and saving large dataframes using for loop in R
#
# Tags: ['c#', 'asp.net-core', 'visual-studio-2019', 'generic-list', 'connected-services']
# Title: Visual Studio Project Adding Connected Services using Generic List Fails
#
# Tags: ['python']
# Title: How to install numpy and pandas in python
#
# Tags: ['android', 'firebase', 'kotlin', 'google-cloud-firestore']
# Title: How can i finish my function in Firestore listener?
#
# Tags: ['firebase', 'unity3d', 'google-cloud-functions']
# Title: Can you use Unity / Firebase Auth with C# google cloud functions?
#
# Tags: ['tcl']
# Title: Write a procedure to generate a single list, by reading the user input from command line in TCL
#
# Tags: ['reactjs', 'firebase', 'react-native', 'expo', 'react-navigation']
# Title: can&#39;t find variable: user. I am using firebase auth and the latest SDK, expo SDK 42, react navigation 6.x.x
#
# Tags: ['python', 'pandas', 'dataframe']
# Title: Group values in pandas dataframe by min
#
# Tags: ['html', 'typescript', 'window.open']
# Title: How can I open a url in a new window on safari iphone
#
# Tags: ['json', 'azure', 'azure-powershell', 'azure-management-groups']
# Title: Not able to create new Management Group in Azure - New-AzManagementGroup
#
# Tags: ['java', 'android', 'image', 'capture']
# Title: How can I capture part of the screen?
#
# Tags: ['java', 'android', 'singleton']
# Title: Android Singleton
#
# Tags: ['google-cloud-platform', 'google-cloud-shell']
# Title: Wrong keyboard on Google Cloud Shell
#
# Tags: ['com', 'vb6', 'exe', 'permission-denied', 'dcom']
# Title: Why I got error 70: Permission denied when write data to a variable
#
# Tags: ['python', 'pandas']
# Title: Pandas drop rows appearing above/below string match
#
# Tags: ['go', 'gorilla']
# Title: How can I make type assertions against an anonymous function?
#
# Tags: ['python', 'twitter', 'error-handling', 'bz2', 'ijson']
# Title: Python ijson - parse error: trailing garbage // bz2.decompress()
#
# Tags: ['go', 'polymorphism']
# Title: Polymorphism in Go. How to create common IModel interface with Merge, Compare methods, that need to work with another IModel argument?
#
# Tags: ['octave']
# Title: How do you make an if-statement in Octave that would switch the row that has a zero pivot element with the row that has a nonzero pivot element?
#
# Tags: ['django', 'django-rest-framework']
# Title: drf create manytomany fields
#
# Tags: ['django']
# Title: Django | admin account page group display
#
# Tags: ['typescript', 'constructor', 'overloading']
# Title: Constructor overload in TypeScript
#
# Tags: ['python', 'pygame']
# Title: Why wont my button work while program runs?
#
# Tags: ['c++', 'c++17', 'implicit-conversion']
# Title: How can I get C++ to prefer converting char* to string_view instead of bool?
#
# Tags: ['r', 'performance', 'shiny', 'profiling', 'profvis']
# Title: Improve profvis performance for profiling shiny app
#
# Tags: ['google-app-engine', 'google-cloud-platform', 'google-cloud-load-balancer']
# Title: HTTP(S) Regional traffic route to specific resource - Google Cloud
#
# Tags: ['pandas', 'dataframe', 'group-by', 'apply']
# Title: When using &#39;df.groupby(column).apply()&#39; get the groupby column within the &#39;apply&#39; context?
#
# Tags: ['python', 'csv']
# Title: _csv.Error: line contains NUL for a new CSV file
